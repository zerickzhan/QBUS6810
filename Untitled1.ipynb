# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
bank_test=pd.read_csv('bank_test.csv')

# %%
bank_test.head()
# Out:
#    id  age          job   marital  education default  balance housing loan  \
# 0   0   43  blue-collar   married    primary      no      517     yes   no
# 1   1   53   unemployed  divorced  secondary      no      587      no   no
# 2   2   28  blue-collar    single    primary      no      722     yes   no
# 3   3   47  blue-collar   married  secondary      no     2548     yes   no
# 4   4   37  blue-collar   married  secondary      no     1403      no   no
#
#     contact  day month  campaign  pdays  previous poutcome
# 0  cellular   20   apr         2    263         7  failure
# 1  cellular   19   nov         1     -1         0  unknown
# 2   unknown   21   may         1     -1         0  unknown
# 3  cellular   11   may         1    368         1    other
# 4   unknown    9   oct         1     -1         0  unknown

# %%
print(bank_test.describe())
# Out:
#                  id           age       balance           day      campaign  \
# count  15824.000000  15824.000000  15824.000000  15824.000000  15824.000000
# mean    7911.500000     40.976744   1379.472194     15.703172      2.710250
# std     4568.139665     10.609848   3046.619450      8.310297      2.988449
# min        0.000000     18.000000  -8019.000000      1.000000      1.000000
# 25%     3955.750000     33.000000     78.000000      8.000000      1.000000
# 50%     7911.500000     39.000000    459.000000     16.000000      2.000000
# 75%    11867.250000     48.000000   1456.250000     21.000000      3.000000
# max    15823.000000     95.000000  98417.000000     31.000000     58.000000
#
#               pdays      previous
# count  15824.000000  15824.000000
# mean      40.741974      0.579626
# std      100.985777      2.910575
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
print(bank_test.isnull().sum())
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.pairplot(bank_test)
plt.show()
